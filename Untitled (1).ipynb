# %% [markdown]
# ## Plotly go

# %% [markdown]
# ---

# %%
import plotly.graph_objs as go
import pandas as pd
import numpy as np
import plotly.express as px

# %%
df_ = px.data.gapminder()

# %%
df_
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
#group by year and continent
df=df_.groupby(['year','continent']).sum().reset_index()
df.head()
# Out:
#    year continent                                            country  \
# 0  1952    Africa  AlgeriaAngolaBeninBotswanaBurkina FasoBurundiC...
# 1  1952  Americas  ArgentinaBoliviaBrazilCanadaChileColombiaCosta...
# 2  1952      Asia  AfghanistanBahrainBangladeshCambodiaChinaHong ...
# 3  1952    Europe  AlbaniaAustriaBelgiumBosnia and HerzegovinaBul...
# 4  1952   Oceania                               AustraliaNew Zealand
#
#     lifeExp         pop      gdpPercap  \
# 0  2035.046   237640501   65133.768223
# 1  1331.996   345152446  101976.563805
# 2  1528.375  1395357351  171450.972133
# 3  1932.255   418120846  169831.723043
# 4   138.510    10686006   20596.171300
#
#                                            iso_alpha  iso_num
# 0  DZAAGOBENBWABFABDICMRCAFTCDCOMCODCOGCIVDJIEGYG...    23859
# 1  ARGBOLBRACANCHLCOLCRICUBDOMECUSLVGTMHTIHNDJAMM...     9843
# 2  AFGBHRBGDKHMCHNHKGINDIDNIRNIRQISRJPNJORKORKORK...    13354
# ...

# %%
import plotly.graph_objects as go


fig = go.Figure(
    data=[
        go.Bar(
            name='Asia',
            x=df[df.continent == 'Asia']['year'],
            y=df[df.continent == 'Asia']['pop']
        ),
        go.Bar(
            name='Europe',
            x=df[df.continent == 'Europe']['year'],
            y=df[df.continent == 'Europe']['pop']
        )
    ]
)
fig.show()

# %%
country1= 'United States'
country2='Japan'

# %%
fig = go.Figure()

# %%
fig.add_trace(
    go.Scatter(
        x=df_[df_.country==country1].year,
        y=df_[df_.country==country1].lifeExp,
        name=country1,
        text=df_[df_.country==country1].lifeExp,
        mode= 'lines+text', 
        textposition='bottom right'
    )
)

fig.add_trace(
    go.Scatter(
        x=df_[df_.country==country2].year,
        y=df_[df_.country==country2].lifeExp,
        name=country2,
        mode='lines',
        line=dict(
            color='sienna',
            width=5
        )
    )
)


fig.show()

# %%
fig.update_layout(
    margin=dict(
        l=5,
        r=5,
        t=50,
        b=5
    )
)
fig.show()

# %%
df = pd.read_csv('2010YumaAZ.csv')
days = ['TUESDAY','WEDNESDAY','THURSDAY','FRIDAY','SATURDAY','SUNDAY','MONDAY']

# %%
df
# Out:
#      LST_DATE      DAY LST_TIME  T_HR_AVG
# 0    20100601  TUESDAY     0:00      25.2
# 1    20100601  TUESDAY     1:00      24.1
# 2    20100601  TUESDAY     2:00      24.4
# 3    20100601  TUESDAY     3:00      24.9
# 4    20100601  TUESDAY     4:00      22.8
# ..        ...      ...      ...       ...
# 163  20100607   MONDAY    19:00      39.4
# 164  20100607   MONDAY    20:00      38.5
# 165  20100607   MONDAY    21:00      37.0
# 166  20100607   MONDAY    22:00      34.7
# 167  20100607   MONDAY    23:00      32.6
#
# [168 rows x 4 columns]

# %%
data = []

for day in days:
    trace = go.Scatter(
        x=df['LST_TIME'],
        y=df[df['DAY']==day]['T_HR_AVG'],
        mode='lines',
        name=day
    )

    data.append(trace)

layout = go.Layout(
    title='Daily temperatures from June 1-7, 2010 in Yuma, Arizona',
    hovermode='closest'
)

fig = go.Figure(data=data, layout=layout)

# %%
fig.show()

# %%
a_df = pd.read_csv('abalone.csv')

# %%
a_df
# Out:
#      sex  length  diameter  height  whole_weight  shucked_weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       viscera_weight  shell_weight  rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
fig = go.Figure(
    data= [
        go.Histogram(
            x=a_df[(a_df['length']>=0) & (a_df['length']<=1)]['length'],
            xbins=dict(
                size=0.02
            )
        )
    ]
)

fig.show()

fig.update_layout(
    title='Shell lengths from the Abalone dataset',
    xaxis_title='length'
)

# %%
df = pd.read_csv('mpg.csv')

# %%
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
import plotly.graph_objects as go

data = [
    go.Scatter(
        x=df['displacement'],
        y=df['acceleration'],
        mode='markers',
        marker=dict(color='blue'),
        customdata=df['name'],  # Attach the name column to each point
        hovertemplate=
            'Displacement: %{x}<br>' +
            'Acceleration: %{y}<br>' +
            'Name: %{customdata}<extra></extra>'
    )
]

layout = go.Layout(
    title='Vehicle acceleration vs displacement',
    yaxis_title='Acceleration = seconds to reach 60mph',
    xaxis_title='Displacement',
    height=500,
    hovermode='closest'
)

fig = go.Figure(
    data=data,
    layout=layout
)

fig.show()

# %%
from dash import Dash, dcc 
import dash_bootstrap_components as dbc

# %%
# Build your components
app = Dash(__name__, external_stylesheets=[dbc.themes.BOOTSTRAP]) #the theme is BOOTSTRAP. You may choose other theme
mytext = dcc.Markdown(children="# Hello World - let's build web apps in Python!")
# Customize your own Layout
app.layout = dbc.Container([mytext])
# Run app
if __name__=='__main__':
    app.run(port=8051)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8051/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
app = Dash(__name__, external_stylesheets=[dbc.themes.SOLAR])
mytext = dcc.Markdown(children='') 
myinput = dbc.Input(value="# Hello World - let's build web apps in Python!") 
# Customize your own Layout
app.layout = dbc.Container([mytext, myinput])
# Callback allows components to interact
@app.callback(
    Output(mytext, component_property='children'), 
    Input(myinput, component_property='value') 
)
def update_title(user_input):  # function arguments come from the component property of the Input
    return user_input  # returned objects are assigned to the component property of the Output
# Run app
if __name__=='__main__':
    app.run_server(port=8053)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[253], line 8
#       5 app.layout = dbc.Container([mytext, myinput])
#       6 # Callback allows components to interact
#       7 @app.callback(
# ----> 8     Output(mytext, component_property='children'),
#       9     Input(myinput, component_property='value')
#      10 )
#      11 def update_title(user_input):  # function arguments come from the component property of the Input
#      12     return user_input  # returned objects are assigned to the component property of the Output
#      13 # Run app
#
# NameError: name 'Output' is not defined
